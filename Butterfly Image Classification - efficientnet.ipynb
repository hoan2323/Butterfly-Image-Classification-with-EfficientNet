# %%
import pandas as pd
import os
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.applications import EfficientNetB3
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.layers import BatchNormalization, Activation
# Out:
# 2025-06-20 01:39:27.792547: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750383568.256285      35 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750383568.366777      35 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# Load CSV file
df = pd.read_csv('/kaggle/input/ai-1904-dpl-302-m-butterfly-image-classification/Training_set.csv')

# Encode labels
le = LabelEncoder()
df['label_encoded'] = le.fit_transform(df['label'])

# Số lớp phân loại
num_classes = df['label_encoded'].nunique()

# %%
train_df, val_df = train_test_split(df, test_size=0.2, stratify=df['label_encoded'], random_state=42)

# %%
# ImageDataGenerator with data augmentation for training
train_gen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=45,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2],
    fill_mode='nearest'
)

# Only rescaling for validation data
val_gen = ImageDataGenerator(rescale=1./255)

# Create train data generator
train_data = train_gen.flow_from_dataframe(
    dataframe=train_df,
    directory='/kaggle/input/ai-1904-dpl-302-m-butterfly-image-classification/train/train',
    x_col='filename',
    y_col='label',
    target_size=(300, 300),
    class_mode='categorical',
    batch_size=32,
    shuffle=True
)

# Create validation data generator
val_data = val_gen.flow_from_dataframe(
    dataframe=val_df,
    directory='/kaggle/input/ai-1904-dpl-302-m-butterfly-image-classification/train/train',
    x_col='filename',
    y_col='label',
    target_size=(300, 300),
    class_mode='categorical',
    batch_size=32,
    shuffle=False
)
# Out:
# Found 4000 validated image filenames belonging to 75 classes.
# Found 1000 validated image filenames belonging to 75 classes.

# %%
base_model = EfficientNetB3(weights='imagenet', include_top=False, input_shape=(300, 300, 3))

x = GlobalAveragePooling2D()(base_model.output)
x = Dense(512)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dropout(0.5)(x)

x = Dense(256)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dropout(0.3)(x)

x = Dense(128)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dropout(0.1)(x)

output = Dense(num_classes, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=output)

# Compile model
model.compile(optimizer=Adam(learning_rate=1e-4),
              loss='categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# I0000 00:00:1750383602.143640      35 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1750383602.144389      35 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb3_notop.h5
# 43941136/43941136 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
callbacks = [
    EarlyStopping(
        monitor='val_accuracy',             # Theo dõi độ chính xác trên tập validation
        patience=15,                        # Dừng nếu không cải thiện sau 10 epoch
        restore_best_weights=True,
        verbose=1
    ),
    ModelCheckpoint(
        filepath='best_butterfly_model.keras',  # Tên file lưu mô hình tốt nhất
        monitor='val_accuracy',                 # Lưu mô hình khi val_accuracy tốt hơn
        save_best_only=True,
        save_weights_only=False,                # Lưu toàn bộ mô hình (not just weights)
        mode='max',
        verbose=1
    ),
    ReduceLROnPlateau(
        monitor='val_accuracy',                 # Giảm learning rate khi val acc không cải thiện
        factor=0.5,
        patience=5,
        min_lr=1e-6,
        verbose=1
    )
]
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=70,
    callbacks=callbacks
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/70
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1750383696.888775      98 service.cc:148] XLA service 0x78dbd0001ee0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1750383696.890280      98 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1750383696.890302      98 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1750383705.447497      98 cuda_dnn.cc:529] Loaded cuDNN version 90300
# E0000 00:00:1750383727.080430      98 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1750383727.237709      98 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1750383727.829005      98 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1750383727.975750      98 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1750383728.330128      98 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1750383728.476952      98 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1750383729.034747      98 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1750383729.204111      98 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1750383729.373755      98 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# I0000 00:00:1750383763.417517      98 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.0220 - loss: 4.5629
# Epoch 1: val_accuracy improved from -inf to 0.01600, saving model to best_butterfly_model.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 312s 1s/step - accuracy: 0.0221 - loss: 4.5620 - val_accuracy: 0.0160 - val_loss: 4.3380 - learning_rate: 1.0000e-04
# Epoch 2/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 842ms/step - accuracy: 0.0752 - loss: 4.0561
# Epoch 2: val_accuracy improved from 0.01600 to 0.03100, saving model to best_butterfly_model.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 112s 895ms/step - accuracy: 0.0754 - loss: 4.0551 - val_accuracy: 0.0310 - val_loss: 4.3530 - learning_rate: 1.0000e-04
# Epoch 3/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 826ms/step - accuracy: 0.2023 - loss: 3.4944
# Epoch 3: val_accuracy improved from 0.03100 to 0.06100, saving model to best_butterfly_model.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 110s 880ms/step - accuracy: 0.2025 - loss: 3.4936 - val_accuracy: 0.0610 - val_loss: 4.2170 - learning_rate: 1.0000e-04
# Epoch 4/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 825ms/step - accuracy: 0.3366 - loss: 3.0812
# Epoch 4: val_accuracy improved from 0.06100 to 0.24200, saving model to best_butterfly_model.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 110s 879ms/step - accuracy: 0.3369 - loss: 3.0803 - val_accuracy: 0.2420 - val_loss: 3.7068 - learning_rate: 1.0000e-04
# Epoch 5/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 820ms/step - accuracy: 0.4860 - loss: 2.6486
# Epoch 5: val_accuracy improved from 0.24200 to 0.60100, saving model to best_butterfly_model.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 110s 875ms/step - accuracy: 0.4861 - loss: 2.6481 - val_accuracy: 0.6010 - val_loss: 2.5303 - learning_rate: 1.0000e-04
# Epoch 6/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 821ms/step - accuracy: 0.5806 - loss: 2.3327
# Epoch 6: val_accuracy did not improve from 0.60100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 108s 859ms/step - accuracy: 0.5808 - loss: 2.3321 - val_accuracy: 0.4770 - val_loss: 2.8540 - learning_rate: 1.0000e-04
# Epoch 7/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 827ms/step - accuracy: 0.6439 - loss: 2.0632
# Epoch 7: val_accuracy did not improve from 0.60100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 109s 866ms/step - accuracy: 0.6440 - loss: 2.0625 - val_accuracy: 0.5540 - val_loss: 2.6848 - learning_rate: 1.0000e-04
# Epoch 8/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 805ms/step - accuracy: 0.7120 - loss: 1.7828
# Epoch 8: val_accuracy improved from 0.60100 to 0.83600, saving model to best_butterfly_model.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 108s 858ms/step - accuracy: 0.7122 - loss: 1.7822 - val_accuracy: 0.8360 - val_loss: 1.2803 - learning_rate: 1.0000e-04
# Epoch 9/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 821ms/step - accuracy: 0.7875 - loss: 1.5273
# Epoch 9: val_accuracy improved from 0.83600 to 0.85200, saving model to best_butterfly_model.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 110s 874ms/step - accuracy: 0.7875 - loss: 1.5269 - val_accuracy: 0.8520 - val_loss: 1.0331 - learning_rate: 1.0000e-04
# Epoch 10/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 815ms/step - accuracy: 0.8210 - loss: 1.3287
# Epoch 10: val_accuracy did not improve from 0.85200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 107s 854ms/step - accuracy: 0.8211 - loss: 1.3282 - val_accuracy: 0.8190 - val_loss: 1.1587 - learning_rate: 1.0000e-04
# Epoch 11/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 824ms/step - accuracy: 0.8499 - loss: 1.1337
# Epoch 11: val_accuracy improved from 0.85200 to 0.88500, saving model to best_butterfly_model.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 110s 877ms/step - accuracy: 0.8499 - loss: 1.1335 - val_accuracy: 0.8850 - val_loss: 0.7346 - learning_rate: 1.0000e-04
# Epoch 12/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 826ms/step - accuracy: 0.8652 - loss: 1.0124
# Epoch 12: val_accuracy did not improve from 0.88500
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 109s 865ms/step - accuracy: 0.8652 - loss: 1.0121 - val_accuracy: 0.8690 - val_loss: 0.7829 - learning_rate: 1.0000e-04
# Epoch 13/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 834ms/step - accuracy: 0.8922 - loss: 0.8685
# Epoch 13: val_accuracy improved from 0.88500 to 0.89000, saving model to best_butterfly_model.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 111s 888ms/step - accuracy: 0.8922 - loss: 0.8683 - val_accuracy: 0.8900 - val_loss: 0.6241 - learning_rate: 1.0000e-04
# Epoch 14/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 834ms/step - accuracy: 0.8939 - loss: 0.7816
# Epoch 14: val_accuracy did not improve from 0.89000
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 110s 873ms/step - accuracy: 0.8939 - loss: 0.7813 - val_accuracy: 0.8790 - val_loss: 0.6462 - learning_rate: 1.0000e-04
# Epoch 15/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 834ms/step - accuracy: 0.9234 - loss: 0.6598
# Epoch 15: val_accuracy did not improve from 0.89000
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 110s 875ms/step - accuracy: 0.9234 - loss: 0.6598 - val_accuracy: 0.6450 - val_loss: 1.6927 - learning_rate: 1.0000e-04
# Epoch 16/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 830ms/step - accuracy: 0.9242 - loss: 0.6062
# Epoch 16: val_accuracy did not improve from 0.89000
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 109s 868ms/step - accuracy: 0.9241 - loss: 0.6062 - val_accuracy: 0.2760 - val_loss: 3.2420 - learning_rate: 1.0000e-04
# Epoch 17/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 836ms/step - accuracy: 0.9360 - loss: 0.5215
# Epoch 17: val_accuracy improved from 0.89000 to 0.89400, saving model to best_butterfly_model.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 112s 890ms/step - accuracy: 0.9360 - loss: 0.5214 - val_accuracy: 0.8940 - val_loss: 0.5330 - learning_rate: 1.0000e-04
# Epoch 18/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 830ms/step - accuracy: 0.9451 - loss: 0.4599
# Epoch 18: val_accuracy did not improve from 0.89400
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 109s 869ms/step - accuracy: 0.9451 - loss: 0.4599 - val_accuracy: 0.8550 - val_loss: 0.6738 - learning_rate: 1.0000e-04
# Epoch 19/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 824ms/step - accuracy: 0.9470 - loss: 0.4243
# Epoch 19: val_accuracy did not improve from 0.89400
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 108s 862ms/step - accuracy: 0.9470 - loss: 0.4242 - val_accuracy: 0.8390 - val_loss: 0.7597 - learning_rate: 1.0000e-04
# Epoch 20/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 832ms/step - accuracy: 0.9566 - loss: 0.3696
# Epoch 20: val_accuracy did not improve from 0.89400
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 109s 871ms/step - accuracy: 0.9565 - loss: 0.3697 - val_accuracy: 0.8740 - val_loss: 0.5926 - learning_rate: 1.0000e-04
# Epoch 21/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 827ms/step - accuracy: 0.9613 - loss: 0.3410
# Epoch 21: val_accuracy did not improve from 0.89400
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 109s 866ms/step - accuracy: 0.9613 - loss: 0.3410 - val_accuracy: 0.8930 - val_loss: 0.4245 - learning_rate: 1.0000e-04
# Epoch 22/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 832ms/step - accuracy: 0.9650 - loss: 0.2918
# Epoch 22: val_accuracy did not improve from 0.89400
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 109s 871ms/step - accuracy: 0.9650 - loss: 0.2919 - val_accuracy: 0.6390 - val_loss: 1.6255 - learning_rate: 1.0000e-04
# Epoch 23/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 829ms/step - accuracy: 0.9659 - loss: 0.2707
# Epoch 23: val_accuracy did not improve from 0.89400
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 109s 868ms/step - accuracy: 0.9659 - loss: 0.2706 - val_accuracy: 0.8620 - val_loss: 0.5695 - learning_rate: 5.0000e-05
# Epoch 24/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 829ms/step - accuracy: 0.9766 - loss: 0.2437
# Epoch 24: val_accuracy improved from 0.89400 to 0.93500, saving model to best_butterfly_model.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 111s 885ms/step - accuracy: 0.9766 - loss: 0.2437 - val_accuracy: 0.9350 - val_loss: 0.2873 - learning_rate: 5.0000e-05
# Epoch 25/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 820ms/step - accuracy: 0.9810 - loss: 0.2185
# Epoch 25: val_accuracy did not improve from 0.93500
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 108s 858ms/step - accuracy: 0.9810 - loss: 0.2185 - val_accuracy: 0.9280 - val_loss: 0.3317 - learning_rate: 5.0000e-05
# Epoch 26/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 834ms/step - accuracy: 0.9810 - loss: 0.2172
# Epoch 26: val_accuracy improved from 0.93500 to 0.93800, saving model to best_butterfly_model.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 111s 888ms/step - accuracy: 0.9810 - loss: 0.2172 - val_accuracy: 0.9380 - val_loss: 0.2912 - learning_rate: 5.0000e-05
# Epoch 27/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 823ms/step - accuracy: 0.9754 - loss: 0.2041
# Epoch 27: val_accuracy did not improve from 0.93800
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 108s 862ms/step - accuracy: 0.9755 - loss: 0.2041 - val_accuracy: 0.9350 - val_loss: 0.2973 - learning_rate: 5.0000e-05
# Epoch 28/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 834ms/step - accuracy: 0.9854 - loss: 0.1796
# Epoch 28: val_accuracy did not improve from 0.93800
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 110s 874ms/step - accuracy: 0.9854 - loss: 0.1796 - val_accuracy: 0.8830 - val_loss: 0.4818 - learning_rate: 5.0000e-05
# Epoch 29/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 846ms/step - accuracy: 0.9869 - loss: 0.1674
# Epoch 29: val_accuracy did not improve from 0.93800
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 111s 886ms/step - accuracy: 0.9869 - loss: 0.1675 - val_accuracy: 0.8980 - val_loss: 0.4289 - learning_rate: 5.0000e-05
# Epoch 30/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 838ms/step - accuracy: 0.9832 - loss: 0.1756
# Epoch 30: val_accuracy did not improve from 0.93800
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 110s 878ms/step - accuracy: 0.9833 - loss: 0.1755 - val_accuracy: 0.9250 - val_loss: 0.3358 - learning_rate: 5.0000e-05
# Epoch 31/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 843ms/step - accuracy: 0.9860 - loss: 0.1522
# Epoch 31: val_accuracy did not improve from 0.93800
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 111s 882ms/step - accuracy: 0.9860 - loss: 0.1523 - val_accuracy: 0.9310 - val_loss: 0.3332 - learning_rate: 5.0000e-05
# Epoch 32/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 836ms/step - accuracy: 0.9853 - loss: 0.1473
# Epoch 32: val_accuracy did not improve from 0.93800
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 110s 877ms/step - accuracy: 0.9853 - loss: 0.1473 - val_accuracy: 0.9360 - val_loss: 0.3081 - learning_rate: 2.5000e-05
# Epoch 33/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 831ms/step - accuracy: 0.9893 - loss: 0.1412
# Epoch 33: val_accuracy improved from 0.93800 to 0.93900, saving model to best_butterfly_model.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 111s 887ms/step - accuracy: 0.9893 - loss: 0.1412 - val_accuracy: 0.9390 - val_loss: 0.2822 - learning_rate: 2.5000e-05
# Epoch 34/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 832ms/step - accuracy: 0.9885 - loss: 0.1314
# Epoch 34: val_accuracy improved from 0.93900 to 0.94600, saving model to best_butterfly_model.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 112s 889ms/step - accuracy: 0.9885 - loss: 0.1314 - val_accuracy: 0.9460 - val_loss: 0.2665 - learning_rate: 2.5000e-05
# Epoch 35/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 831ms/step - accuracy: 0.9915 - loss: 0.1250
# Epoch 35: val_accuracy did not improve from 0.94600
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 109s 871ms/step - accuracy: 0.9915 - loss: 0.1250 - val_accuracy: 0.9450 - val_loss: 0.2694 - learning_rate: 2.5000e-05
# Epoch 36/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 822ms/step - accuracy: 0.9914 - loss: 0.1310
# Epoch 36: val_accuracy did not improve from 0.94600
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 108s 862ms/step - accuracy: 0.9914 - loss: 0.1310 - val_accuracy: 0.9420 - val_loss: 0.2902 - learning_rate: 2.5000e-05
# Epoch 37/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 833ms/step - accuracy: 0.9873 - loss: 0.1260
# Epoch 37: val_accuracy did not improve from 0.94600
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 109s 872ms/step - accuracy: 0.9873 - loss: 0.1260 - val_accuracy: 0.9330 - val_loss: 0.3054 - learning_rate: 2.5000e-05
# Epoch 38/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 830ms/step - accuracy: 0.9890 - loss: 0.1201
# Epoch 38: val_accuracy did not improve from 0.94600
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 109s 870ms/step - accuracy: 0.9890 - loss: 0.1201 - val_accuracy: 0.9320 - val_loss: 0.3128 - learning_rate: 2.5000e-05
# Epoch 39/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 823ms/step - accuracy: 0.9914 - loss: 0.1108
# Epoch 39: val_accuracy did not improve from 0.94600
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 109s 865ms/step - accuracy: 0.9914 - loss: 0.1108 - val_accuracy: 0.9390 - val_loss: 0.2898 - learning_rate: 2.5000e-05
# Epoch 40/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 832ms/step - accuracy: 0.9908 - loss: 0.1186
# Epoch 40: val_accuracy did not improve from 0.94600
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 109s 871ms/step - accuracy: 0.9908 - loss: 0.1185 - val_accuracy: 0.9240 - val_loss: 0.3168 - learning_rate: 1.2500e-05
# Epoch 41/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 821ms/step - accuracy: 0.9931 - loss: 0.1019
# Epoch 41: val_accuracy improved from 0.94600 to 0.94900, saving model to best_butterfly_model.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 110s 875ms/step - accuracy: 0.9931 - loss: 0.1019 - val_accuracy: 0.9490 - val_loss: 0.2734 - learning_rate: 1.2500e-05
# Epoch 42/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 838ms/step - accuracy: 0.9956 - loss: 0.1010
# Epoch 42: val_accuracy did not improve from 0.94900
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 110s 876ms/step - accuracy: 0.9955 - loss: 0.1010 - val_accuracy: 0.9470 - val_loss: 0.2708 - learning_rate: 1.2500e-05
# Epoch 43/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 828ms/step - accuracy: 0.9909 - loss: 0.1098
# Epoch 43: val_accuracy improved from 0.94900 to 0.95000, saving model to best_butterfly_model.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 111s 882ms/step - accuracy: 0.9909 - loss: 0.1098 - val_accuracy: 0.9500 - val_loss: 0.2723 - learning_rate: 1.2500e-05
# Epoch 44/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 828ms/step - accuracy: 0.9916 - loss: 0.1077
# Epoch 44: val_accuracy did not improve from 0.95000
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 109s 867ms/step - accuracy: 0.9916 - loss: 0.1077 - val_accuracy: 0.9500 - val_loss: 0.2750 - learning_rate: 1.2500e-05
# Epoch 45/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 830ms/step - accuracy: 0.9959 - loss: 0.0987
# Epoch 45: val_accuracy did not improve from 0.95000
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 109s 870ms/step - accuracy: 0.9959 - loss: 0.0987 - val_accuracy: 0.9470 - val_loss: 0.2768 - learning_rate: 1.2500e-05
# Epoch 46/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 831ms/step - accuracy: 0.9924 - loss: 0.0961
# Epoch 46: val_accuracy did not improve from 0.95000
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 109s 872ms/step - accuracy: 0.9924 - loss: 0.0962 - val_accuracy: 0.9460 - val_loss: 0.2721 - learning_rate: 1.2500e-05
# Epoch 47/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 816ms/step - accuracy: 0.9906 - loss: 0.1092
# Epoch 47: val_accuracy did not improve from 0.95000
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 107s 855ms/step - accuracy: 0.9906 - loss: 0.1091 - val_accuracy: 0.9500 - val_loss: 0.2759 - learning_rate: 1.2500e-05
# Epoch 48/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 818ms/step - accuracy: 0.9930 - loss: 0.0997
# Epoch 48: val_accuracy did not improve from 0.95000
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 107s 857ms/step - accuracy: 0.9930 - loss: 0.0996 - val_accuracy: 0.9440 - val_loss: 0.2812 - learning_rate: 1.2500e-05
# Epoch 49/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 837ms/step - accuracy: 0.9932 - loss: 0.0904
# Epoch 49: val_accuracy did not improve from 0.95000
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 110s 875ms/step - accuracy: 0.9932 - loss: 0.0904 - val_accuracy: 0.9500 - val_loss: 0.2787 - learning_rate: 6.2500e-06
# Epoch 50/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 824ms/step - accuracy: 0.9897 - loss: 0.0978
# Epoch 50: val_accuracy improved from 0.95000 to 0.95100, saving model to best_butterfly_model.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 110s 878ms/step - accuracy: 0.9897 - loss: 0.0978 - val_accuracy: 0.9510 - val_loss: 0.2785 - learning_rate: 6.2500e-06
# Epoch 51/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 838ms/step - accuracy: 0.9966 - loss: 0.0807
# Epoch 51: val_accuracy improved from 0.95100 to 0.95200, saving model to best_butterfly_model.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 112s 892ms/step - accuracy: 0.9966 - loss: 0.0807 - val_accuracy: 0.9520 - val_loss: 0.2768 - learning_rate: 6.2500e-06
# Epoch 52/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 821ms/step - accuracy: 0.9916 - loss: 0.0925
# Epoch 52: val_accuracy did not improve from 0.95200
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 108s 860ms/step - accuracy: 0.9916 - loss: 0.0924 - val_accuracy: 0.9500 - val_loss: 0.2749 - learning_rate: 6.2500e-06
# Epoch 53/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 824ms/step - accuracy: 0.9930 - loss: 0.0875
# Epoch 53: val_accuracy improved from 0.95200 to 0.95300, saving model to best_butterfly_model.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 110s 877ms/step - accuracy: 0.9930 - loss: 0.0875 - val_accuracy: 0.9530 - val_loss: 0.2741 - learning_rate: 6.2500e-06
# Epoch 54/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 820ms/step - accuracy: 0.9937 - loss: 0.0855
# Epoch 54: val_accuracy did not improve from 0.95300
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 108s 858ms/step - accuracy: 0.9938 - loss: 0.0855 - val_accuracy: 0.9510 - val_loss: 0.2771 - learning_rate: 6.2500e-06
# Epoch 55/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 825ms/step - accuracy: 0.9933 - loss: 0.0918
# Epoch 55: val_accuracy did not improve from 0.95300
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 108s 864ms/step - accuracy: 0.9933 - loss: 0.0918 - val_accuracy: 0.9500 - val_loss: 0.2791 - learning_rate: 6.2500e-06
# Epoch 56/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 822ms/step - accuracy: 0.9960 - loss: 0.0825
# Epoch 56: val_accuracy did not improve from 0.95300
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 108s 861ms/step - accuracy: 0.9960 - loss: 0.0825 - val_accuracy: 0.9490 - val_loss: 0.2768 - learning_rate: 6.2500e-06
# Epoch 57/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 824ms/step - accuracy: 0.9954 - loss: 0.0850
# Epoch 57: val_accuracy did not improve from 0.95300
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 108s 862ms/step - accuracy: 0.9954 - loss: 0.0850 - val_accuracy: 0.9490 - val_loss: 0.2802 - learning_rate: 6.2500e-06
# Epoch 58/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 821ms/step - accuracy: 0.9933 - loss: 0.0916
# Epoch 58: val_accuracy did not improve from 0.95300
#
# Epoch 58: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 108s 860ms/step - accuracy: 0.9933 - loss: 0.0915 - val_accuracy: 0.9490 - val_loss: 0.2777 - learning_rate: 6.2500e-06
# Epoch 59/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 823ms/step - accuracy: 0.9927 - loss: 0.0818
# Epoch 59: val_accuracy did not improve from 0.95300
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 108s 861ms/step - accuracy: 0.9927 - loss: 0.0817 - val_accuracy: 0.9510 - val_loss: 0.2799 - learning_rate: 3.1250e-06
# Epoch 60/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 816ms/step - accuracy: 0.9949 - loss: 0.0825
# Epoch 60: val_accuracy did not improve from 0.95300
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 107s 856ms/step - accuracy: 0.9949 - loss: 0.0825 - val_accuracy: 0.9500 - val_loss: 0.2806 - learning_rate: 3.1250e-06
# Epoch 61/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 820ms/step - accuracy: 0.9959 - loss: 0.0765
# Epoch 61: val_accuracy did not improve from 0.95300
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 108s 860ms/step - accuracy: 0.9959 - loss: 0.0766 - val_accuracy: 0.9520 - val_loss: 0.2783 - learning_rate: 3.1250e-06
# Epoch 62/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 818ms/step - accuracy: 0.9961 - loss: 0.0783
# Epoch 62: val_accuracy did not improve from 0.95300
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 108s 857ms/step - accuracy: 0.9961 - loss: 0.0783 - val_accuracy: 0.9490 - val_loss: 0.2768 - learning_rate: 3.1250e-06
# Epoch 63/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - accuracy: 0.9968 - loss: 0.0756
# Epoch 63: val_accuracy did not improve from 0.95300
#
# Epoch 63: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 107s 851ms/step - accuracy: 0.9968 - loss: 0.0756 - val_accuracy: 0.9520 - val_loss: 0.2792 - learning_rate: 3.1250e-06
# Epoch 64/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 820ms/step - accuracy: 0.9945 - loss: 0.0860
# Epoch 64: val_accuracy improved from 0.95300 to 0.95400, saving model to best_butterfly_model.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 110s 872ms/step - accuracy: 0.9945 - loss: 0.0860 - val_accuracy: 0.9540 - val_loss: 0.2797 - learning_rate: 1.5625e-06
# Epoch 65/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 830ms/step - accuracy: 0.9942 - loss: 0.0784
# Epoch 65: val_accuracy did not improve from 0.95400
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 109s 869ms/step - accuracy: 0.9942 - loss: 0.0784 - val_accuracy: 0.9540 - val_loss: 0.2799 - learning_rate: 1.5625e-06
# Epoch 66/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 824ms/step - accuracy: 0.9946 - loss: 0.0799
# Epoch 66: val_accuracy did not improve from 0.95400
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 108s 862ms/step - accuracy: 0.9946 - loss: 0.0799 - val_accuracy: 0.9540 - val_loss: 0.2800 - learning_rate: 1.5625e-06
# Epoch 67/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 822ms/step - accuracy: 0.9961 - loss: 0.0843
# Epoch 67: val_accuracy did not improve from 0.95400
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 108s 861ms/step - accuracy: 0.9961 - loss: 0.0843 - val_accuracy: 0.9530 - val_loss: 0.2797 - learning_rate: 1.5625e-06
# Epoch 68/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - accuracy: 0.9941 - loss: 0.0771
# Epoch 68: val_accuracy did not improve from 0.95400
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 107s 850ms/step - accuracy: 0.9941 - loss: 0.0771 - val_accuracy: 0.9530 - val_loss: 0.2795 - learning_rate: 1.5625e-06
# Epoch 69/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 819ms/step - accuracy: 0.9906 - loss: 0.0922
# Epoch 69: val_accuracy did not improve from 0.95400
#
# Epoch 69: ReduceLROnPlateau reducing learning rate to 1e-06.
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 108s 857ms/step - accuracy: 0.9907 - loss: 0.0921 - val_accuracy: 0.9540 - val_loss: 0.2814 - learning_rate: 1.5625e-06
# Epoch 70/70
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 829ms/step - accuracy: 0.9951 - loss: 0.0827
# Epoch 70: val_accuracy did not improve from 0.95400
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 109s 868ms/step - accuracy: 0.9951 - loss: 0.0827 - val_accuracy: 0.9540 - val_loss: 0.2810 - learning_rate: 1.0000e-06
# Restoring model weights from the end of the best epoch: 64.

# %%
from tensorflow.keras.models import load_model

# Load mô hình tốt nhất đã lưu
model = load_model("/kaggle/working/best_butterfly_model.keras")

# %%
import os
from tensorflow.keras.preprocessing import image

# Lấy danh sách file ảnh test
test_dir = "/kaggle/input/ai-1904-dpl-302-m-butterfly-image-classification/test/test"
test_files = [f for f in os.listdir(test_dir) if f.endswith(".jpg")]

# Tạo danh sách ảnh đã resize và chuẩn hóa
img_array = []
img_ids = []

for fname in test_files:
    img_path = os.path.join(test_dir, fname)
    img = image.load_img(img_path, target_size=(300, 300))
    img_tensor = image.img_to_array(img) / 255.0
    img_array.append(img_tensor)
    img_ids.append(fname)

img_array = np.array(img_array)

# %%
# Dự đoán
predictions = model.predict(img_array)

# Chuyển sang index class
predicted_indices = np.argmax(predictions, axis=1)

# Giải mã lại thành tên loài bướm
predicted_labels = le.inverse_transform(predicted_indices)
# Out:
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 26s 332ms/step

# %%
# Tạo DataFrame kết quả
results_df = pd.DataFrame({
    "ID": img_ids,
    "label": predicted_labels
})

# Xem thử kết quả
print(results_df.head())

# Lưu ra CSV nếu muốn
results_df.to_csv("predictions.csv", index=False)
# Out:
#               ID                   label
# 0  Image_747.jpg         ELBOWED PIERROT
# 1  Image_561.jpg  MILBERTS TORTOISESHELL
# 2  Image_345.jpg              PINE WHITE
# 3  Image_844.jpg        MANGROVE SKIPPER
# 4  Image_270.jpg      CHECQUERED SKIPPER
